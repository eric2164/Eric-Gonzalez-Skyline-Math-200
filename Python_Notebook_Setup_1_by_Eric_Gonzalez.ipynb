# %% [markdown]
# <a href="https://colab.research.google.com/github/eric2164/Eric-Gonzalez-Skyline-Math-200/blob/main/Python_Notebook_Setup_1_by_Eric_Gonzalez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question #1 : Is there an association between the amount of times eating fast food in the past 7 days and hours spent outside during a typical summer week?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1:
#
# ![image.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
df['H4GH8'].dtype
# Out:
# dtype('O')

# %%
df['Fast_food_consumed'] = df['H4GH8']
df['Fast_food_consumed'].dtype
# Out:
# dtype('O')

# %%
df['Fast_food_consumed'] = pd.to_numeric(df['Fast_food_consumed'], errors = 'coerce')
df['Fast_food_consumed'].dtype
# Out:
# dtype('float64')

# %%
df['Fast_food_consumed'] = df['Fast_food_consumed'].loc[ df['Fast_food_consumed'] < 996]
df['Fast_food_consumed'] = df['Fast_food_consumed'].loc[df['Fast_food_consumed'] != ' ']
df['Fast_food_consumed'] = df['Fast_food_consumed'].loc[df['Fast_food_consumed'] != '.']
df['Fast_food_consumed'].max()
# Out:
# 99.0

# %%
#Graphs and tables or statistics

# %%
pip install researchpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
rp.summary_cont(df['Fast_food_consumed'])
# Out:
#              Variable       N    Mean      SD      SE  95% Conf.  Interval
# 0  Fast_food_consumed  5079.0  2.3761  3.4339  0.0482     2.2816    2.4705

# %%
rp.summarize(df['Fast_food_consumed'])
# Out:
#                  Name     N    Mean Median Variance      SD      SE  \
# 0  Fast_food_consumed  5079  2.3761    2.0   11.792  3.4339  0.0482
#
#   95% Conf. Interval
# 0   [2.2816, 2.4705]

# %%
df['Fast_food_consumed'].describe()
# Out:
# count    5079.000000
# mean        2.376058
# std         3.433947
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        99.000000
# Name: Fast_food_consumed, dtype: float64

# %%
sns.histplot(x = 'Fast_food_consumed', data = df, bins = 25, binwidth = 2, kde = True, color = 'red', stat = 'percent')
# Out:
# <Axes: xlabel='Fast_food_consumed', ylabel='Percent'>

# %%
sns.boxplot(x = 'Fast_food_consumed', data = df, color = 'red')
# Out:
# <Axes: xlabel='Fast_food_consumed'>

# %% [markdown]
# Codebook 2:
#
# ![image.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
df['H4DA17'].dtype
# Out:
# dtype('O')

# %%
df['Hours_spent_outside'] = df['H4DA17']
df['Hours_spent_outside'].dtype
# Out:
# dtype('O')

# %%
df['Hours_spent_outside'] = pd.to_numeric(df['Hours_spent_outside'], errors = 'coerce')
df['Hours_spent_outside'].dtype
# Out:
# dtype('float64')

# %%
df['Hours_spent_outside'] = df['Hours_spent_outside'].loc[ df['Hours_spent_outside'] < 995]
df['Hours_spent_outside'] = df['Hours_spent_outside'].loc[df['Hours_spent_outside'] != ' ']
df['Hours_spent_outside'] = df['Hours_spent_outside'].loc[df['Hours_spent_outside'] != '.']
df['Hours_spent_outside'].max()
# Out:
# 99.0

# %%
#Graphs and tables or statistics

# %%
rp.summary_cont(df['Hours_spent_outside'])
# Out:
#               Variable       N     Mean       SD      SE  95% Conf.  Interval
# 0  Hours_spent_outside  5007.0  14.0471  16.8306  0.2379    13.5808   14.5134

# %%
rp.summarize(df['Hours_spent_outside'])
# Out:
#                   Name     N     Mean Median  Variance       SD      SE  \
# 0  Hours_spent_outside  5007  14.0471    8.0  283.2707  16.8306  0.2379
#
#    95% Conf. Interval
# 0  [13.5808, 14.5134]

# %%
df['Hours_spent_outside'].describe()
# Out:
# count    5007.000000
# mean       14.047134
# std        16.830646
# min         0.000000
# 25%         3.000000
# 50%         8.000000
# 75%        20.000000
# max        99.000000
# Name: Hours_spent_outside, dtype: float64

# %%
sns.histplot(x = 'Hours_spent_outside', data = df, bins = 50, binwidth = 2, kde = True, color = 'green', stat = 'percent')
# Out:
# <Axes: xlabel='Hours_spent_outside', ylabel='Percent'>

# %%
sns.boxplot(x = 'Hours_spent_outside', data = df, color = 'green')
# Out:
# <Axes: xlabel='Hours_spent_outside'>
